# %%
import pandas as pd

# %%
air=pd.read_csv(r"D:\VARNN\data\air.csv")

# %%
print(air.isnull().sum())
# Out:
# date_time        0
# PT08.S1(CO)      0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# PT08.S3(NOx)     0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %%
df = air.dropna()

# %%
air
# Out:
#             date_time  PT08.S1(CO)  C6H6(GT)  PT08.S2(NMHC)  PT08.S3(NOx)  \
# 0     3/10/2004 18:00         1360      11.9           1046          1056
# 1     3/10/2004 19:00         1292       9.4            955          1174
# 2     3/10/2004 20:00         1402       9.0            939          1140
# 3     3/10/2004 21:00         1376       9.2            948          1092
# 4     3/10/2004 22:00         1272       6.5            836          1205
# ...               ...          ...       ...            ...           ...
# 9352   4/4/2005 10:00         1314      13.5           1101           539
# 9353   4/4/2005 11:00         1163      11.4           1027           604
# 9354   4/4/2005 12:00         1142      12.4           1063           603
# 9355   4/4/2005 13:00         1003       9.5            961           702
# 9356   4/4/2005 14:00         1071      11.9           1047           654
#
#       PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH
# ...
